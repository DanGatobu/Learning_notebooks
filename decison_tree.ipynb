# %%
# %matplotlib inline
import pandas as pd 
import numpy as np 
import matplotlib.pyplot  as plt
import seaborn as sns

iris=pd.read_csv('Iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
features=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
iris_holder=iris.dropna()
iris2=iris_holder

data=iris_holder[features].copy()
dataset=iris2.drop('Id',axis=1)
dataset['Labels']=dataset['Species']
dataset=dataset.drop('Species',axis=1)
dataset
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Labels
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# data=((data-data.min())/(data.max()-data.min()))
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
data.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
import random 
from pprint import pprint

# %%
def splitdata(data,testsize):
    if isinstance(testsize,float):
        testsize=int(round((testsize*len(data))))
    indexes=data.index.tolist()
    testindexes =random.sample(population=indexes,k=testsize)
    datatest=data.loc[testindexes]
    datatrain=data.drop(testindexes)
    
    
        
        
    return datatest,datatrain

# %%
random.seed(9)
testdata,traindata=splitdata(dataset,0.2)
testdata
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm           Labels
# 118            7.7           2.6            6.9           2.3   Iris-virginica
# 95             5.7           3.0            4.2           1.2  Iris-versicolor
# 68             6.2           2.2            4.5           1.5  Iris-versicolor
# 35             5.0           3.2            1.2           0.2      Iris-setosa
# 47             4.6           3.2            1.4           0.2      Iris-setosa
# 1              4.9           3.0            1.4           0.2      Iris-setosa
# 86             6.7           3.1            4.7           1.5  Iris-versicolor
# 128            6.4           2.8            5.6           2.1   Iris-virginica
# 149            5.9           3.0            5.1           1.8   Iris-virginica
# 20             5.4           3.4            1.7           0.2      Iris-setosa
# 85             6.0           3.4            4.5           1.6  Iris-versicolor
# ...

# %%
data2=traindata.values
data2
labelcolumn=data2[:,-1]
uniqueclasses,count_uniqueclasses=np.unique(labelcolumn,return_counts=True)
count_uniqueclasses
# Out:
# array([38, 42, 40], dtype=int64)

# %%
def checkpurity(data):
    labelcolumn=data[:,-1]
    uniqueclasses=np.unique(labelcolumn)
    if len(uniqueclasses)==1:
        return True
    else:
        return False

# %%
def classify(data):
    labelcolumn=data[:,-1]
    uniqueclasses,count_uniqueclasses=np.unique(labelcolumn,return_counts=True)
    index=count_uniqueclasses.argmax()
    classification=uniqueclasses[index]
    return classification

# %%
print(traindata['PetalWidthCm'].dtype)
# Out:
# float64

# %%
# traindata['PetalWidthCm'] = traindata['PetalWidthCm'].astype(float)
# traindata['PetalWidthCm'] = pd.to_numeric(traindata['PetalWidthCm'], errors='coerce')
w=classify(traindata[traindata.PetalWidthCm >2.3].values)
w
# Out:
# 'Iris-virginica'

# %%
s=checkpurity(traindata[traindata.PetalWidthCm <2.3].values)
s
# Out:
# False

# %%
_,datacount=traindata.shape
datacount
# Out:
# 5

# %%
def get_potentialsplits(data):
    potentialsplits={}
    _,datacount=data.shape
    for columindex in range(datacount-1):
        potentialsplits[columindex]=[]
        values=data[:,columindex]
        uniquevalues=np.unique(values)
        for index in range(len(uniquevalues)):
            if index !=0:
                currentvalue=uniquevalues[index]
                previousvalue=uniquevalues[index-1]
                potentialsplit=(currentvalue+previousvalue)/2
                potentialsplits[columindex].append(potentialsplit)
    return potentialsplits

# %%
traindata
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Labels
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# 5              5.4           3.9            1.7           0.4     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 143            6.8           3.2            5.9           2.3  Iris-virginica
# 144            6.7           3.3            5.7           2.5  Iris-virginica
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
#
# [120 rows x 5 columns]

# %%
potentialsplitsg=get_potentialsplits(traindata.values)
potentialsplitsg
# Out:
# {0: [4.45,
#   4.55,
#   4.65,
#   4.75,
#   4.85,
#   4.95,
#   5.05,
#   5.15,
#   5.25,
#   5.35,
#   5.45,
#   5.55,
#   5.65,
#   5.75,
#   5.85,
#   5.95,
#   6.05,
#   6.15,
#   6.25,
#   6.35,
#   6.45,
#   6.55,
#   6.65,
#   6.75,
#   6.85,
#   6.95,
#   7.05,
#   7.15,
#   7.25,
#   7.449999999999999,
#   7.65,
#   7.800000000000001],
#  1: [2.25,
#   2.3499999999999996,
#   2.45,
#   2.55,
#   2.6500000000000004,
#   2.75,
#   2.8499999999999996,
#   2.95,
#   3.05,
#   3.1500000000000004,
#   3.25,
#   3.3499999999999996,
#   3.45,
#   3.55,
#   3.6500000000000004,
#   3.75,
#   3.8499999999999996,
#   3.95,
#   4.05,
#   4.25],
#  2: [1.1,
#   1.25,
#   1.35,
#   1.45,
#   1.55,
#   1.65,
#   1.7999999999999998,
#   2.45,
#   3.15,
#   3.4,
#   3.55,
#   3.6500000000000004,
#   3.75,
#   3.8499999999999996,
#   3.95,
#   4.05,
#   4.15,
#   4.25,
#   4.35,
#   4.45,
#   4.55,
#   4.65,
#   4.75,
#   4.85,
#   4.95,
#   5.05,
#   5.15,
#   5.25,
#   5.35,
#   5.45,
# ...

# %%
sns.lmplot(data=traindata,x='PetalWidthCm',y='PetalLengthCm',hue='Labels',fit_reg=False,size=6,aspect=1.5)
plt.vlines(x=potentialsplitsg[3],ymin=1,ymax=7)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
def split(data,splitcolumn,splitvalue):
    splitcolumn_values=data[:,splitcolumn]
    databelow=data[splitcolumn_values<splitvalue]
    dataabove=data[splitcolumn_values>splitvalue]
    return databelow,dataabove

# %%
columnw=3
splitvalue=0.8

# %%
databelow,dataabove=split(data2,columnw,splitvalue)

# %%
def calculatentropy(data):
    labelcolumn=data[:,-1]
    _,counts=np.unique(labelcolumn,return_counts=True)
    probabilities=(counts/counts.sum())
    entropy=sum(probabilities*-np.log2(probabilities))
    return entropy

# %%
calculatentropy(databelow)
# Out:
# 0.0

# %%
def overall_calculateentropy(databelow,databove):
    datapoints=len(databelow)+len(databove)
    p_databelow=len(databelow)/datapoints
    p_databove=len(dataabove)/datapoints
    overallentropy=(p_databelow*calculatentropy(databelow)+(p_databove)*calculatentropy(dataabove))
    return overallentropy

# %%
overall_calculateentropy(databelow,dataabove)
# Out:
# 0.6830400735540036

# %%
def bestsplit(data,potentialsplits):
    overallentropy=999
    for columnindex in potentialsplits:
        for value in potentialsplits[columnindex]:
            databelow,databove=split(data,splitcolumn=columnindex,splitvalue=value)
            current_entropy=overall_calculateentropy(databelow,databove)
            if current_entropy<=overallentropy:
                overallentropy=current_entropy
                bestsplit_column=columnindex
                bestsplit_value=value
    return bestsplit_column,bestsplit_value

# %%
bestsplit(data2,potentialsplitsg)
# Out:
# (3, 0.75)

# %%
def decision_tree_algorithm(df, counter=0,min_sample=2,max_depth=5):
# data preparations
    if counter == 0:
        global columnheaders
        columnheaders=df.columns
        data=df.values
    else:
        data=df
    #base case
    if checkpurity(data) or (len(data)<min_sample)or(counter==max_depth):
        classification=classify(data)
        return classification
    # recursive part
    else:
        counter +=1
        # helper functions
        potential_splits = get_potentialsplits(data)
        split_column, split_value = bestsplit(data, potential_splits)
        data_below, data_above = split(data, split_column, split_value)
        # instantiate sub-tree
        featurename=columnheaders[split_column]
        question = "{} <= {}".format(featurename, split_value)
        sub_tree={question: []}
        # find answers (recursion)
        yes_answer=decision_tree_algorithm(data_below, counter,min_sample)
        no_answer=decision_tree_algorithm(data_above, counter,min_sample)
        sub_tree[question].append(yes_answer)
        sub_tree[question].append(no_answer)
        if yes_answer==no_answer:
            sub_tree=yes_answer
        else:
            return sub_tree

# %%
tree=decision_tree_algorithm(traindata,max_depth=1)
pprint(tree)
# Out:
# {'PetalWidthCm <= 0.75': ['Iris-setosa',
#                           {'PetalWidthCm <= 1.35': ['Iris-versicolor',
#                                                     {'PetalLengthCm <= 4.45': ['Iris-versicolor',
#                                                                                {'SepalWidthCm <= 2.35': ['Iris-virginica',
#                                                                                                          None]}]}]}]}

# %%
example=testdata.iloc[2]
example
# Out:
# SepalLengthCm                6.2
# SepalWidthCm                 2.2
# PetalLengthCm                4.5
# PetalWidthCm                 1.5
# Labels           Iris-versicolor
# Name: 68, dtype: object

# %%
def classify_example(example, tree):
    question = list(tree.keys())[0]
    feature_name, comparison_operator, value = question.split()
    # ask question
    if example[feature_name] <= float(value):
        answer=tree [question][0]
    else:
        answer=tree[question][1]
    # base case
    if not isinstance(answer, dict):
        return answer
    # recursice part
    else:
        residual_tree=answer
    return classify_example(example, residual_tree)

# %%
classify_example(example,tree)
# Out:
# 'Iris-virginica'

# %%
def calculate_accuracy(df, tree):
    df ["classification"]= df.apply(classify_example, axis=1, args=(tree,))
    df["classification_correct"]= df.classification == df.Labels
    accuracy = df.classification_correct.mean()
    return accuracy

# %%
calculate_accuracy(testdata,tree)
# Out:
# 0.5666666666666667

# %%
testdata
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 118            7.7           2.6            6.9           2.3
# 95             5.7           3.0            4.2           1.2
# 68             6.2           2.2            4.5           1.5
# 35             5.0           3.2            1.2           0.2
# 47             4.6           3.2            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 86             6.7           3.1            4.7           1.5
# 128            6.4           2.8            5.6           2.1
# 149            5.9           3.0            5.1           1.8
# 20             5.4           3.4            1.7           0.2
# 85             6.0           3.4            4.5           1.6
# 10             5.4           3.7            1.5           0.2
# 97             6.2           2.9            4.3           1.3
# 43             5.0           3.5            1.6           0.6
# ...

# %%
train_df, test_df = splitdata(dataset, testsize=0.3)
tree=decision_tree_algorithm(train_df, max_depth=3)
accuracy = calculate_accuracy (test_df, tree)
accuracy
# Out:
# 0.9428571428571428
